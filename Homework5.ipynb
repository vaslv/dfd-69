# %% [markdown]
# <a href="https://colab.research.google.com/github/vaslv/dfd-69/blob/main/Homework5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('dfd-69/Расходы (Ответы) - Ответы на форму (1).csv')

# %%
df.describe()
# Out:
#               Сумма
# count     36.000000
# mean    4193.611111
# std     8673.937037
# min      100.000000
# 25%      675.000000
# 50%     1500.000000
# 75%     3775.000000
# max    50000.000000

# %%
df.columns
# Out:
# Index(['Отметка времени', 'Месяц', 'Название', 'Сумма', 'Категория',
#        'Регулярная трата', 'Месяц с номером'],
#       dtype='object')

# %%
df_categories = df[['Категория','Сумма']]

# %%
df_categories.groupby('Категория').sum()
# Out:
#                Сумма
# Категория
# Здоровье     10200.0
# Продукты     23500.0
# Развлечения  24200.0
# Спорт         7800.0
# Техника      78800.0
# Транспорт     2870.0
# Услуги        3600.0
